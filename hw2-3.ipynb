# %% [markdown]
# <hr style="height:5px;border-width:2;color:gray;background-color:#000000">
# <center><h1>CS 144 - Spring 2025 - Homework 2</h1></center>
# <center><h1>Due: Sunday, April 20, 2025 @ 11:59pm</h1></center>

# %% [markdown]
# ## Read *all* cells carefully and answer all parts (both text and code)

# %% [markdown]
# ### Enter your information below:
#
# <div style="color: #000000;background-color: #EEEEFF">
#     Your Name (submitter):  <br>
#     Your student ID (submitter):
# <br>
# <br>
# <b>By submitting this notebook, I assert that the work below is my own work, completed for this course.  Except where explicitly cited, none of the portions of this notebook are duplicated from anyone else's work or my own previous work.</b>
# <br>
# <br>
# <b>Instruction for submissions:</B> when you have completed this homework, download this .ipynb file to your computer by left-clicking on the file name, and submit to <a href="https://elearn.ucr.edu/">Canvas</A> by the deadline.
# <br>
# <br>
# <B>Late work:</B> Each student is granted five "late days" which can be used (in integer units) on any of the homework. If a more dire situation arises, please contact the instructor. DO NOT RESORT TO CHEATING.
# </div>

# %% [markdown]
# <hr style="height:5px;border-width:2;color:gray;background-color:#000000">
# <center><h1>Question 1: Tries</h1></center>
# <br>
# As we discussed in class, a trie is a type of search tree, a tree data structure used for locating specific keys from within a set. These keys are most often strings, with links between nodes defined not by the entire key, but by individual characters. In order to access a key (to recover its value, change it, or remove it), the trie is traversed depth-first, following the links between nodes, which represent each character in the key.
#
# In the following two problems, we will work on the construction problem and the matching problem using tries.

# %% [markdown]
# <div style="color: #000000;background-color: #EEFFEE">
#     <font size=+2>Question 1.1:</font> <font size=+1>(10 points)</font>
# <br>
#
# Solve the <A HREF="https://cogniterra.org/lesson/51898/step/4?unit=43387">Code Challenge: Solve the Trie Construction Problem</A>. Submit your solution to the challenge on Cogniterra and paste your Python below.
# <br>
# No tree/graph/tries libraries allowed. You do not need to implement a memory-efficient trie structure for this problem. Nested dictionaries work well for this problem, but feel free to implement it in other ways.
#
# Notes:
# <UL>
# <LI>For the auto-grader in Cogniterra to work the list of edges has to match exactly the required format. You might have to convert numbers into strings using str() to get the correct format.</LI>
# <LI>The wget below fetches the Cogniterra example input file</LI>
# </UL>
# </div>

# %%
# get the input
# !wget http://www.cs.ucr.edu/~stelo/cs144/data/hw2_test1.txt
# Out:
# --2025-04-21 17:28:45--  http://www.cs.ucr.edu/~stelo/cs144/data/hw2_test1.txt
# Resolving www.cs.ucr.edu (www.cs.ucr.edu)... 169.235.30.15
# Connecting to www.cs.ucr.edu (www.cs.ucr.edu)|169.235.30.15|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 14 [text/plain]
# Saving to: ‘hw2_test1.txt.1’
#
# hw2_test1.txt.1     100%[===================>]      14  --.-KB/s    in 0s
#
# 2025-04-21 17:28:45 (2.03 MB/s) - ‘hw2_test1.txt.1’ saved [14/14]

# %%
## YOUR CODE HERE
## no tree/graph/tries libraries allowed

def make_trie(words): 
    """ creates a trie (e.g., implemented as a nested dictionary) from a list of words """
    trie = {0: {}}  #initialize the trie, starting with root node
    node_cnt = 1
    for word in words: 
        curr=0
        for char in word:
            if char in trie[curr]:
                curr= trie[curr][char] #we check if the character is already in the trie, if it is, we keep traversing
            else:
                trie[node_cnt]={}
                trie[curr][char]= node_cnt #we update the node, we will have to add a new one to the trie since we didn't find it at first
                curr = node_cnt
                node_cnt = node_cnt + 1
    return trie
                
def print_trie(trie): 
    """ prints (recursively, via DFS) the trie as an edge list according to the format required """
    def print_helper(node):
        for char in trie[node]:
            child= trie[node][char]
            print(f"{node}->{child}:{char}")
            print_helper(child)
    return print_helper(0)
        
    
with open("hw2_test12.txt", "r") as f: # open the file
    patterns = [line.rstrip() for line in f if line.strip()]
#print(l)
trie = make_trie(patterns)
print_trie(trie)
# Out:
# 0->1:T
# 1->2:A
# 2->3:G
# 3->4:T
# 4->5:C
# 5->6:C
# 6->7:C
# 7->8:T
# 8->9:T
# 9->10:C
# 10->11:G
# 11->12:A
# 12->13:T
# 13->14:G
# 14->15:A
# 15->16:A
# 16->17:T
# 17->18:C
# 18->19:G
# 19->20:T
# 20->21:T
# 21->22:T
# 22->23:C
# 23->24:A
# 24->25:T
# 25->26:C
# 26->27:C
# 27->28:C
# 28->29:A
# 29->30:T
# 30->31:C
# 31->32:C
# 32->33:G
# 33->34:C
# 34->35:T
# 35->36:G
# 36->37:G
# 37->38:T
# 38->39:T
# 39->40:T
# 40->41:C
# 41->42:T
# 42->43:G
# 43->44:A
# 44->45:A
# 45->46:G
# 46->47:T
# 47->48:C
# 48->49:A
# 49->50:T
# 50->51:C
# 51->52:G
# 52->53:T
# 53->54:T
# 54->55:T
# 55->56:G
# 56->57:G
# 57->58:T
# 58->59:G
# 59->60:G
# 60->61:G
# 61->62:G
# 62->63:A
# 63->64:T
# 64->65:G
# 65->66:G
# 66->67:C
# 67->68:G
# 68->69:G
# 69->70:A
# 70->71:C
# 71->72:G
# 72->73:C
# 73->74:C
# 74->75:C
# 75->76:G
# 76->77:C
# 77->78:G
# 78->79:A
# 79->80:T
# 3->3340:G
# 3340->3341:G
# 3341->3342:T
# 3342->3343:G
# 3343->3344:T
# 3344->3345:A
# 3345->3346:T
# 3346->3347:T
# 3347->3348:T
# 3348->3349:C
# 3349->3350:G
# 3350->3351:A
# 3351->3352:T
# 3352->3353:G
# 3353->3354:C
# 3354->3355:T
# 3355->3356:G
# 3356->3357:A
# 3357->3358:A
# 3358->3359:T
# 3359->3360:A
# 3360->3361:C
# 3361->3362:T
# 3362->3363:G
# 3363->3364:G
# 3364->3365:T
# 3365->3366:C
# 3366->3367:C
# 3367->3368:A
# 3368->3369:C
# 3369->3370:G
# 3370->3371:T
# 3371->3372:A
# 3372->3373:C
# 3373->3374:A
# 3374->3375:G
# 3375->3376:G
# 3376->3377:C
# 3377->3378:G
# 3378->3379:T
# 3379->3380:A
# 3380->3381:T
# 3381->3382:C
# 3382->3383:C
# 3383->3384:T
# 3384->3385:T
# 3385->3386:C
# 3386->3387:T
# 3387->3388:C
# 3388->3389:C
# 3389->3390:G
# 3390->3391:G
# 3391->3392:T
# 3392->3393:A
# 3393->3394:G
# 3394->3395:T
# 3395->3396:C
# 3396->3397:T
# 3397->3398:T
# 3398->3399:A
# 3399->3400:G
# 3400->3401:C
# 3401->3402:G
# 3402->3403:G
# 3403->3404:G
# 3404->3405:G
# 3405->3406:C
# 3406->3407:C
# 3407->3408:G
# 3408->3409:T
# 3409->3410:C
# 3410->3411:C
# 3411->3412:T
# 3412->3413:C
# 3413->3414:T
# 3414->3415:T
# 3415->3416:C
# 3416->3417:C
# 3417->3418:T
# 3418->3419:A
# 3419->3420:T
# 3420->3421:C
# 3421->3422:A
# 3422->3423:A
# 3423->3424:T
# 3424->3425:G
# 3425->3426:G
# 3426->3427:G
# 3427->3428:G
# 3428->3429:T
# 3429->3430:T
# 3430->3431:A
# 2->868:A
# 868->869:G
# 869->870:T
# 870->871:T
# 871->872:G
# 872->873:T
# 873->874:T
# 874->875:T
# 875->876:A
# 876->877:A
# 877->878:G
# 878->879:A
# 879->880:G
# 880->881:G
# 881->882:C
# 882->883:C
# 883->884:G
# 884->885:C
# 885->886:T
# 886->887:C
# 887->888:T
# 888->889:A
# 889->890:T
# 890->891:C
# 891->892:G
# 892->893:G
# 893->894:G
# 894->895:C
# 895->896:C
# 896->897:G
# 897->898:A
# 898->899:A
# 899->900:T
# 900->901:G
# 901->902:C
# 902->903:T
# 903->904:T
# 904->905:T
# 905->906:T
# 906->907:T
# 907->908:T
# 908->909:T
# 909->910:T
# 910->911:T
# 911->912:A
# 912->913:T
# 913->914:T
# 914->915:G
# 915->916:C
# 916->917:G
# 917->918:G
# 918->919:G
# 919->920:T
# 920->921:G
# 921->922:T
# 922->923:G
# 923->924:C
# 924->925:T
# 925->926:T
# 926->927:A
# 927->928:A
# 928->929:A
# 929->930:T
# 930->931:G
# 931->932:T
# 932->933:T
# 933->934:T
# 934->935:G
# 935->936:C
# 936->937:G
# 937->938:G
# 938->939:C
# 939->940:A
# 940->941:T
# 941->942:A
# 942->943:T
# 943->944:C
# 944->945:C
# 945->946:A
# 946->947:A
# 947->948:T
# 948->949:C
# 949->950:G
# 950->951:G
# 951->952:C
# 952->953:T
# 870->2872:G
# 2872->2873:T
# 2873->2874:T
# 2874->2875:G
# 2875->2876:A
# 2876->2877:C
# 2877->2878:T
# 2878->2879:T
# 2879->2880:A
# 2880->2881:C
# 2881->2882:C
# 2882->2883:C
# 2883->2884:C
# 2884->2885:G
# 2885->2886:G
# 2886->2887:T
# 2887->2888:T
# 2888->2889:C
# 2889->2890:A
# 2890->2891:G
# 2891->2892:T
# 2892->2893:A
# 2893->2894:C
# 2894->2895:G
# 2895->2896:G
# 2896->2897:A
# 2897->2898:G
# 2898->2899:G
# 2899->2900:G
# 2900->2901:G
# 2901->2902:G
# 2902->2903:T
# 2903->2904:T
# 2904->2905:G
# 2905->2906:C
# 2906->2907:G
# 2907->2908:A
# 2908->2909:T
# 2909->2910:T
# 2910->2911:A
# 2911->2912:A
# 2912->2913:C
# 2913->2914:A
# 2914->2915:A
# 2915->2916:A
# 2916->2917:C
# 2917->2918:T
# 2918->2919:C
# 2919->2920:C
# 2920->2921:G
# 2921->2922:G
# 2922->2923:G
# 2923->2924:C
# 2924->2925:T
# 2774->2775:T
# 2775->2776:C
# 2776->2777:C
# 2777->2778:T
# 2778->2779:A
# 2779->2780:A
# 2780->2781:A
# 2781->2782:A
# 2782->2783:A
# 2783->2784:G
# 2784->2785:T
# 2785->2786:T
# 2786->2787:C
# 2787->2788:A
# 2788->2789:G
# 2789->2790:G
# 2709->2791:G
# 2791->2792:G
# 2792->2793:G
# 2793->2794:G
# 2794->2795:T
# 2795->2796:T
# 2796->2797:G
# 2797->2798:A
# 2798->2799:A
# 2799->2800:G
# 2800->2801:A
# 2801->2802:T
# 2802->2803:C
# 2803->2804:G
# 2804->2805:C
# 2805->2806:C
# 2806->2807:G
# 2807->2808:A
# 2808->2809:A
# 2809->2810:G
# 2810->2811:G
# 2811->2812:C
# 2812->2813:T
# 2813->2814:C
# 2814->2815:C
# 2815->2816:C
# 2816->2817:A
# 2817->2818:A
# 2818->2819:G
# 2819->2820:C
# 2820->2821:T
# 2821->2822:C
# 2822->2823:G
# 2823->2824:A
# 2824->2825:G
# 2825->2826:A
# 2826->2827:A
# 2827->2828:T
# 2828->2829:C
# 2829->2830:A
# 2830->2831:A
# 2831->2832:C
# 2832->2833:T
# 2833->2834:C
# 2834->2835:G
# 2835->2836:A
# 2836->2837:A
# 2837->2838:A
# 2838->2839:T
# 2839->2840:G
# 2840->2841:G
# 2841->2842:C
# 2842->2843:C
# 2843->2844:T
# 2844->2845:A
# 2845->2846:A
# 2846->2847:G
# 2847->2848:T
# 2848->2849:A
# 2849->2850:T
# 2850->2851:A
# 2851->2852:G
# 2852->2853:C
# 2853->2854:C
# 2854->2855:A
# 2855->2856:C
# 2856->2857:C
# 2857->2858:T
# 2858->2859:A
# 2859->2860:T
# 2860->2861:G
# 2861->2862:G
# 2862->2863:C
# 2863->2864:A
# 2864->2865:A
# 2865->2866:G
# 2866->2867:G
# 2867->2868:C
# 2868->2869:G
# 2869->2870:G
# 2870->2871:A
# 1->173:T
# 173->174:C
# 174->175:T
# 175->176:G
# 176->177:A
# 177->178:G
# 178->179:T
# 179->180:C
# 180->181:T
# 181->182:A
# 182->183:T
# 183->184:G
# 184->185:A
# 185->186:G
# 186->187:A
# 187->188:T
# 188->189:C
# 189->190:C
# 190->191:C
# 191->192:A
# 192->193:T
# 193->194:C
# 194->195:C
# 195->196:G
# 196->197:A
# 197->198:G
# 198->199:T
# 199->200:A
# 200->201:T
# 201->202:A
# 202->203:G
# 203->204:T
# 204->205:T
# 205->206:G
# 206->207:G
# 207->208:T
# 208->209:T
# 209->210:G
# 210->211:C
# 211->212:A
# 212->213:A
# 213->214:T
# 214->215:G
# 215->216:G
# 216->217:T
# 217->218:G
# 218->219:G
# 219->220:A
# 220->221:T
# 221->222:G
# 222->223:T
# 223->224:A
# 224->225:T
# 225->226:A
# 226->227:G
# 227->228:G
# 228->229:C
# 229->230:G
# 230->231:T
# 231->232:C
# 232->233:T
# 233->234:C
# 234->235:A
# 235->236:C
# 236->237:A
# 237->238:T
# 238->239:A
# 239->240:C
# 240->241:A
# 241->242:A
# 242->243:G
# 243->244:A
# 244->245:C
# 245->246:G
# 246->247:A
# 247->248:G
# 248->249:A
# 249->250:G
# 250->251:A
# 251->252:T
# 252->253:G
# 173->344:T
# 344->345:C
# 345->346:G
# 346->347:T
# 347->348:T
# 348->349:A
# 349->350:T
# 350->351:A
# 351->352:G
# 352->353:G
# 353->354:T
# 354->355:A
# 355->356:A
# 356->357:G
# 357->358:C
# 358->359:A
# 359->360:A
# 360->361:G
# 361->362:T
# 362->363:C
# 363->364:A
# 364->365:T
# 365->366:T
# 366->367:T
# 367->368:G
# 368->369:A
# 369->370:A
# 370->371:A
# 371->372:T
# 372->373:T
# 373->374:A
# 374->375:G
# 375->376:A
# 376->377:C
# 377->378:A
# 378->379:T
# 379->380:A
# 380->381:C
# 381->382:C
# 382->383:A
# 383->384:G
# 384->385:A
# 385->386:G
# 386->387:G
# 387->388:G
# 388->389:C
# 389->390:C
# 390->391:T
# 391->392:G
# 392->393:T
# 393->394:T
# 394->395:A
# 395->396:G
# 396->397:G
# 397->398:A
# 398->399:G
# 399->400:A
# 400->401:C
# 401->402:C
# 402->403:A
# 403->404:G
# 404->405:T
# 405->406:C
# 406->407:G
# 407->408:C
# 408->409:T
# 409->410:C
# 410->411:C
# 411->412:G
# 412->413:T
# 413->414:G
# 414->415:T
# 415->416:A
# 416->417:C
# 417->418:T
# 418->419:C
# 419->420:G
# 420->421:G
# 421->422:C
# 422->423:T
# 423->424:T
# 346->3865:C
# 3865->3866:T
# 3866->3867:T
# 3867->3868:T
# 3868->3869:C
# 3869->3870:G
# 3870->3871:T
# 3871->3872:A
# 3872->3873:T
# 3873->3874:G
# 3874->3875:A
# 3875->3876:C
# 3876->3877:C
# 3877->3878:T
# 3878->3879:G
# 3879->3880:G
# 3880->3881:A
# 3881->3882:C
# 3882->3883:G
# 3883->3884:A
# 3884->3885:C
# 3885->3886:C
# 3886->3887:A
# 3887->3888:G
# 3888->3889:C
# 3889->3890:C
# 3890->3891:A
# 3891->3892:A
# 3892->3893:A
# 3893->3894:C
# 3894->3895:T
# 3895->3896:G
# 3896->3897:C
# 3897->3898:A
# 3898->3899:T
# 3899->3900:T
# 3900->3901:G
# 3901->3902:T
# 3902->3903:C
# 3903->3904:G
# 3904->3905:T
# 3905->3906:G
# 3906->3907:T
# 3907->3908:C
# 3908->3909:T
# 3909->3910:A
# 3910->3911:G
# 3911->3912:G
# 3912->3913:T
# 3913->3914:A
# 3914->3915:A
# 3915->3916:G
# 3916->3917:T
# 3917->3918:T
# 3918->3919:G
# 3919->3920:T
# 3920->3921:C
# 3921->3922:T
# 3922->3923:G
# 3923->3924:G
# 3924->3925:A
# 3925->3926:T
# 3926->3927:C
# 3927->3928:A
# 3928->3929:C
# 3929->3930:A
# 3930->3931:C
# 3931->3932:C
# 3932->3933:G
# 3933->3934:C
# 3934->3935:C
# 3935->3936:A
# 3936->3937:T
# 3937->3938:T
# 3938->3939:C
# 3939->3940:T
# 3940->3941:C
# 3941->3942:C
# 3942->3943:G
# 3943->3944:G
# 3944->3945:G
# 173->4822:A
# 4822->4823:G
# 4823->4824:T
# 4824->4825:T
# 4825->4826:A
# 4826->4827:A
# 4827->4828:T
# 4828->4829:G
# 4829->4830:T
# 4830->4831:C
# 4831->4832:C
# 4832->4833:T
# 4833->4834:A
# 4834->4835:C
# 4835->4836:C
# 4836->4837:G
# 4837->4838:A
# 4838->4839:A
# 4839->4840:C
# 4840->4841:T
# 4841->4842:G
# 4842->4843:C
# 4843->4844:G
# 4844->4845:A
# 4845->4846:G
# 4846->4847:G
# 4847->4848:C
# 4848->4849:T
# 4849->4850:T
# 4850->4851:C
# 4851->4852:A
# 4852->4853:T
# 4853->4854:C
# 4854->4855:G
# 4855->4856:A
# 4856->4857:T
# 4857->4858:A
# 4858->4859:T
# 4859->4860:G
# 4860->4861:C
# 4861->4862:C
# 4862->4863:A
# 4863->4864:C
# 4864->4865:T
# 4865->4866:G
# 4866->4867:A
# 4867->4868:T
# 4868->4869:A
# 4869->4870:G
# 4870->4871:G
# 4871->4872:A
# 4872->4873:G
# 4873->4874:A
# 4874->4875:G
# 4875->4876:T
# 4876->4877:A
# 4877->4878:T
# 4878->4879:A
# 4879->4880:A
# 4880->4881:T
# 4881->4882:G
# 4882->4883:C
# 4883->4884:G
# 4884->4885:C
# 4885->4886:G
# 4886->4887:A
# 4887->4888:C
# 4888->4889:A
# 4889->4890:T
# 4890->4891:G
# 4891->4892:C
# 4892->4893:A
# 4893->4894:G
# 4894->4895:T
# 4895->4896:A
# 4896->4897:T
# 4897->4898:G
# 4898->4899:T
# 4899->4900:T
# 4900->4901:A
# 4901->4902:T
# 4902->4903:G
# 4903->4904:A
# 4904->4905:A
# 4905->4906:G
# 4906->4907:C
# 4907->4908:C
# 4908->4909:C
# 4909->4910:G
# 4910->4911:A
# 173->5003:G
# 5003->5004:C
# 5004->5005:G
# 5005->5006:T
# 5006->5007:A
# 5007->5008:G
# 5008->5009:A
# 5009->5010:A
# 5010->5011:A
# 5011->5012:G
# 5012->5013:G
# 5013->5014:T
# 5014->5015:G
# 5015->5016:G
# 5016->5017:G
# 5017->5018:G
# 5018->5019:T
# 5019->5020:A
# 5020->5021:C
# 5021->5022:G
# 5022->5023:G
# 5023->5024:A
# 5024->5025:T
# 5025->5026:A
# 5026->5027:G
# 5027->5028:T
# 5028->5029:T
# 5029->5030:G
# 5030->5031:A
# 5031->5032:A
# 5032->5033:C
# 5033->5034:C
# 5034->5035:A
# 5035->5036:T
# 5036->5037:A
# 5037->5038:C
# 5038->5039:G
# 5039->5040:C
# 5040->5041:A
# 5041->5042:T
# 5042->5043:T
# 5043->5044:C
# 5044->5045:G
# 5045->5046:G
# 5046->5047:C
# 5047->5048:G
# 5048->5049:T
# 5049->5050:T
# 5050->5051:A
# 5051->5052:T
# 5052->5053:A
# 5053->5054:C
# 5054->5055:A
# 5055->5056:C
# 5056->5057:T
# 5057->5058:G
# 5058->5059:C
# 5059->5060:A
# 5060->5061:A
# 5061->5062:A
# 5062->5063:C
# 5063->5064:C
# 5064->5065:A
# 5065->5066:A
# 5066->5067:A
# 5067->5068:G
# 5068->5069:G
# 5069->5070:T
# 5070->5071:T
# 5071->5072:T
# 5072->5073:C
# 5073->5074:G
# 5074->5075:C
# 5075->5076:A
# 5076->5077:C
# 5077->5078:T
# 5078->5079:G
# 5079->5080:A
# 5080->5081:G
# 5081->5082:A
# 5082->5083:G
# 5083->5084:T
# 5084->5085:T
# 5085->5086:A
# 5086->5087:C
# 5087->5088:A
# 5088->5089:C
# 1->607:G
# 607->608:A
# 608->609:A
# 609->610:G
# 610->611:G
# 611->612:T
# 612->613:A
# 613->614:G
# 614->615:G
# 615->616:G
# 616->617:T
# 617->618:C
# 618->619:C
# 619->620:T
# 620->621:G
# 621->622:G
# 622->623:T
# 623->624:T
# 624->625:C
# 625->626:C
# 626->627:C
# 627->628:G
# 628->629:G
# 629->630:C
# 630->631:A
# 631->632:T
# 632->633:A
# 633->634:C
# 634->635:T
# 635->636:G
# 636->637:A
# 637->638:G
# 638->639:A
# 639->640:A
# 640->641:A
# 641->642:A
# 642->643:T
# 643->644:C
# 644->645:T
# 645->646:C
# 646->647:T
# 647->648:A
# 648->649:T
# 649->650:T
# 650->651:T
# 651->652:T
# 652->653:G
# 653->654:T
# 654->655:T
# 655->656:T
# 656->657:C
# 657->658:T
# 658->659:G
# 659->660:C
# 660->661:A
# 661->662:C
# 662->663:T
# 663->664:T
# 664->665:A
# 665->666:T
# 666->667:G
# 667->668:T
# 668->669:C
# 669->670:G
# 670->671:T
# 671->672:C
# 672->673:A
# 673->674:G
# 674->675:A
# 675->676:G
# 676->677:T
# 677->678:A
# 678->679:A
# 679->680:C
# 680->681:C
# 681->682:T
# 682->683:G
# 683->684:C
# 684->685:C
# 607->1940:C
# 1940->1941:C
# 1941->1942:A
# 1942->1943:C
# 1943->1944:A
# 1944->1945:C
# 1945->1946:A
# 1946->1947:C
# 1947->1948:G
# 1948->1949:C
# 1949->1950:T
# 1950->1951:A
# 1951->1952:G
# 1952->1953:C
# 1953->1954:C
# 1954->1955:C
# 1955->1956:G
# 1956->1957:C
# 1957->1958:G
# 1958->1959:G
# 1959->1960:A
# 1960->1961:A
# 1961->1962:A
# 1962->1963:G
# 1963->1964:A
# 1964->1965:T
# 1965->1966:G
# 1966->1967:A
# 1967->1968:G
# 1968->1969:G
# 1969->1970:A
# 1970->1971:G
# 1971->1972:G
# 1972->1973:C
# 1973->1974:T
# 1974->1975:T
# 1975->1976:A
# 1976->1977:T
# 1977->1978:G
# 1978->1979:C
# 1979->1980:C
# 1980->1981:G
# 1981->1982:G
# 1982->1983:T
# 1983->1984:A
# 1984->1985:C
# 1985->1986:G
# 1986->1987:G
# 1987->1988:C
# 1988->1989:G
# 1989->1990:C
# 1990->1991:T
# 1991->1992:T
# 1992->1993:T
# 1993->1994:T
# 1994->1995:A
# 1995->1996:G
# 1996->1997:C
# 1997->1998:A
# 1998->1999:A
# 1999->2000:C
# 2000->2001:T
# 2001->2002:A
# 2002->2003:G
# 2003->2004:G
# 2004->2005:A
# 2005->2006:C
# 2006->2007:A
# 5170->5171:G
# 5171->5172:T
# 5172->5173:A
# 5173->5174:T
# 5174->5175:T
# 5175->5176:A
# 5176->5177:T
# 5177->5178:A
# 5178->5179:A
# 5179->5180:T
# 5180->5181:A
# 5181->5182:G
# 5182->5183:C
# 1214->7432:A
# 7432->7433:A
# 7433->7434:A
# 7434->7435:C
# 7435->7436:G
# 7436->7437:G
# 7437->7438:C
# 7438->7439:T
# 7439->7440:A
# 7440->7441:T
# 7441->7442:T
# 7442->7443:A
# 7443->7444:C
# 7444->7445:G
# 7445->7446:G
# 7446->7447:T
# 7447->7448:C
# 7448->7449:G
# 7449->7450:A
# 7450->7451:C
# 7451->7452:A
# 7452->7453:A
# 7453->7454:A
# 7454->7455:A
# 7455->7456:G
# 7456->7457:G
# 7457->7458:T
# 7458->7459:G
# 7459->7460:A
# 7460->7461:T
# 7461->7462:A
# 7462->7463:A
# 7463->7464:A
# 7464->7465:G
# 7465->7466:A
# 7466->7467:T
# 7467->7468:G
# 7468->7469:T
# 7469->7470:C
# 7470->7471:T
# 7471->7472:C
# 7472->7473:T
# 7473->7474:C
# 7474->7475:A
# 7475->7476:G
# 7476->7477:G
# 7477->7478:T
# 7478->7479:G
# 7479->7480:T
# 7480->7481:C
# 7481->7482:C
# 7482->7483:A
# 7483->7484:A
# 7484->7485:G
# 7485->7486:A
# 7486->7487:A
# 7487->7488:T
# 7488->7489:G
# 7489->7490:C
# 7490->7491:T
# 7491->7492:T
# 7492->7493:T
# 7493->7494:C
# 7494->7495:C
# 7495->7496:G
# 7496->7497:A
# 7497->7498:G
# 7498->7499:T
# 7499->7500:A
# 7500->7501:G
# 7501->7502:T
# 7502->7503:T
# 7503->7504:A
# 7504->7505:T
# 7505->7506:C
# 7506->7507:A
# 7507->7508:C
# 7508->7509:C
# 7509->7510:A
# 7510->7511:G
# 7511->7512:T
# 7512->7513:A
# 7513->7514:G
# 7514->7515:G
# 7515->7516:G
# 7516->7517:C
# 7517->7518:T
# 7518->7519:T
# 7519->7520:G
# 7520->7521:C
# 7521->7522:C
# 7522->7523:T
# 7523->7524:C
# 7524->7525:G
# 7525->7526:G
# 7526->7527:C
# 0->81:G
# 81->82:A
# 82->83:A
# 83->84:G
# 84->85:A
# 85->86:T
# 86->87:G
# 87->88:A
# 88->89:G
# 89->90:G
# 90->91:G
# 91->92:G
# 92->93:G
# 93->94:T
# 94->95:G
# 95->96:T
# 96->97:C
# 97->98:A
# 98->99:C
# 99->100:C
# 100->101:G
# 101->102:T
# 102->103:T
# 103->104:T
# 104->105:C
# 105->106:C
# 106->107:T
# 107->108:T
# 108->109:A
# 109->110:A
# 110->111:T
# 111->112:G
# 112->113:T
# 113->114:T
# 114->115:C
# 115->116:C
# 116->117:C
# 117->118:T
# 118->119:T
# 119->120:T
# 120->121:T
# 121->122:G
# 122->123:G
# 123->124:A
# 124->125:T
# 125->126:G
# 126->127:G
# 127->128:G
# 128->129:G
# 129->130:T
# 130->131:G
# 131->132:A
# 132->133:G
# 133->134:A
# 134->135:C
# 135->136:G
# 136->137:T
# 137->138:G
# 138->139:G
# 139->140:C
# 140->141:C
# 141->142:G
# 142->143:C
# 143->144:C
# 144->145:A
# 145->146:A
# 146->147:A
# 147->148:G
# 148->149:C
# 149->150:C
# 150->151:G
# 151->152:G
# 152->153:A
# 153->154:C
# 154->155:G
# 155->156:T
# 156->157:A
# 157->158:G
# 158->159:C
# 159->160:T
# 160->161:C
# 161->162:A
# 162->163:G
# 163->164:C
# 164->165:G
# 165->166:G
# 166->167:C
# 167->168:A
# 168->169:G
# 169->170:T
# 170->171:G
# 171->172:C
# 82->425:G
# 425->426:T
# 426->427:C
# 427->428:G
# 428->429:A
# 429->430:A
# 430->431:C
# 431->432:C
# 432->433:T
# 433->434:A
# 434->435:G
# 435->436:C
# 436->437:C
# 437->438:C
# 438->439:C
# 439->440:A
# 440->441:G
# 441->442:G
# 442->443:G
# 443->444:A
# 444->445:T
# 445->446:A
# 446->447:T
# 447->448:A
# 448->449:T
# 449->450:A
# 450->451:G
# 451->452:T
# 452->453:T
# 453->454:C
# 454->455:C
# 455->456:A
# 456->457:C
# 457->458:T
# 458->459:G
# 459->460:T
# 460->461:G
# 461->462:A
# 462->463:C
# 463->464:T
# 464->465:A
# 465->466:G
# 466->467:T
# 467->468:T
# 468->469:G
# 469->470:C
# 470->471:C
# 471->472:C
# 472->473:G
# 473->474:A
# 474->475:T
# 475->476:T
# 476->477:G
# 477->478:A
# 478->479:A
# 479->480:T
# 480->481:A
# 481->482:T
# 482->483:T
# 483->484:A
# 484->485:G
# 485->486:C
# 486->487:C
# 487->488:T
# 488->489:C
# 489->490:T
# 490->491:G
# 491->492:G
# 492->493:T
# 493->494:T
# 494->495:T
# 495->496:G
# 496->497:G
# 497->498:C
# 498->499:C
# 499->500:T
# 500->501:G
# 501->502:G
# 502->503:C
# 503->504:T
# 504->505:A
# 505->506:T
# 506->507:T
# 507->508:G
# 508->509:G
# 509->510:G
# 510->511:G
# 426->6505:G
# 6505->6506:C
# 6506->6507:G
# 6507->6508:G
# 6508->6509:G
# 6509->6510:A
# 6510->6511:T
# 6511->6512:A
# 6512->6513:T
# 6513->6514:C
# 6514->6515:C
# 6515->6516:G
# 6516->6517:G
# 6517->6518:G
# 6518->6519:C
# 6519->6520:G
# 6520->6521:C
# 6521->6522:G
# 6522->6523:T
# 6523->6524:C
# 6524->6525:C
# 6525->6526:T
# 6526->6527:G
# 6527->6528:A
# 6528->6529:T
# 6529->6530:G
# 6530->6531:C
# 6531->6532:A
# 6532->6533:A
# 6533->6534:G
# 6534->6535:T
# 6535->6536:T
# 6536->6537:T
# 6537->6538:G
# 6538->6539:G
# 6539->6540:G
# 6540->6541:G
# 6541->6542:A
# 6542->6543:C
# 6543->6544:C
# 6544->6545:C
# 6545->6546:T
# 6546->6547:C
# 6547->6548:G
# 6548->6549:G
# 6549->6550:G
# 6550->6551:G
# 6551->6552:T
# 6552->6553:A
# 6553->6554:G
# 6554->6555:A
# 6555->6556:T
# 6556->6557:G
# 6557->6558:G
# 6558->6559:T
# 6559->6560:T
# 267->268:T
# 268->269:C
# 269->270:G
# 270->271:G
# 271->272:T
# 272->273:C
# 273->274:A
# 274->275:A
# 275->276:T
# 276->277:G
# 277->278:C
# 278->279:A
# 279->280:G
# 280->281:A
# 281->282:G
# 282->283:G
# 283->284:A
# 284->285:C
# 285->286:C
# 286->287:C
# 287->288:C
# 288->289:C
# 289->290:T
# 290->291:A
# 291->292:T
# 292->293:A
# 293->294:G
# 294->295:G
# 295->296:A
# 296->297:T
# 297->298:T
# 298->299:G
# 299->300:G
# 300->301:A
# 301->302:G
# 302->303:G
# 303->304:A
# 304->305:T
# 305->306:G
# 306->307:G
# 307->308:C
# 308->309:C
# 309->310:A
# 310->311:T
# 311->312:A
# 312->313:T
# 313->314:G
# 314->315:A
# 315->316:C
# 316->317:C
# 317->318:C
# 318->319:A
# 319->320:A
# 320->321:C
# 321->322:A
# 322->323:G
# 323->324:T
# 324->325:A
# 325->326:G
# 326->327:G
# 327->328:T
# 328->329:A
# 329->330:T
# 330->331:A
# 331->332:A
# 332->333:C
# 333->334:A
# 334->335:C
# 335->336:C
# 336->337:A
# 337->338:G
# 338->339:G
# 339->340:C
# 340->341:G
# 341->342:C
# 342->343:A
# 256->6142:T
# 6142->6143:T
# 6143->6144:T
# 6144->6145:A
# 6145->6146:A
# 6146->6147:T
# 6147->6148:C
# 6148->6149:T
# 6149->6150:T
# 6150->6151:A
# 6151->6152:T
# 6152->6153:T
# 6153->6154:A
# 6154->6155:G
# 6155->6156:C
# 6156->6157:A
# 6157->6158:T
# 6158->6159:G
# 6159->6160:G
# 6160->6161:A
# 6161->6162:A
# 6162->6163:A
# 6163->6164:T
# 6164->6165:C
# 6165->6166:C
# 6166->6167:G
# 6167->6168:A
# 6168->6169:T
# 6169->6170:C
# 6170->6171:A
# 6171->6172:T
# 6172->6173:T
# 6173->6174:C
# 6174->6175:A
# 6175->6176:T
# 6176->6177:G
# 6177->6178:G
# 6178->6179:C
# 6179->6180:A
# 6180->6181:A
# 6181->6182:T
# 6182->6183:C
# 6183->6184:C
# 6184->6185:A
# 6185->6186:C
# 6186->6187:G
# 6187->6188:C
# 6188->6189:G
# 6189->6190:A
# 6190->6191:A
# 6191->6192:A
# 6192->6193:C
# 6193->6194:A
# 6194->6195:C
# 6195->6196:G
# 6196->6197:T
# 6197->6198:G
# 6198->6199:A
# 6199->6200:A
# 6200->6201:T
# 6201->6202:T
# 6202->6203:T
# 6203->6204:G
# 6204->6205:T
# 6205->6206:A
# 6206->6207:A
# 6207->6208:C
# 6208->6209:G
# 6209->6210:T
# 6210->6211:C
# 6211->6212:C
# 6212->6213:T
# 6213->6214:G
# 6214->6215:G
# 6215->6216:A
# 6216->6217:G
# 6217->6218:G
# 6218->6219:C
# 6219->6220:G
# 6220->6221:G
# 6221->6222:G
# 6222->6223:T
# 6223->6224:G
# 6224->6225:C
# 6225->6226:G
# 6226->6227:C
# 6227->6228:C
# 6228->6229:A
# 6229->6230:G
# 6230->6231:A
# 6231->6232:G
# 6232->6233:A
# 6233->6234:A
# 4242->4243:T
# 4243->4244:C
# 4244->4245:C
# 4245->4246:G
# 4246->4247:C
# 4247->4248:C
# 4248->4249:C
# 4249->4250:C
# 4250->4251:T
# 4251->4252:T
# 4252->4253:T
# 4253->4254:G
# 4254->4255:C
# 4255->4256:C
# 4256->4257:T
# 4257->4258:C
# 4258->4259:T
# 4259->4260:T
# 4260->4261:C
# 4261->4262:T
# 4262->4263:C
# 4263->4264:G
# 4264->4265:T
# 4265->4266:G
# 4266->4267:G
# 4267->4268:T
# 4268->4269:G
# 4269->4270:T
# 4270->4271:T
# 4271->4272:G
# 4272->4273:A
# 4273->4274:C
# 4274->4275:C
# 4275->4276:G
# 4276->4277:G
# 4277->4278:A
# 4278->4279:G
# 4279->4280:G
# 4280->4281:C
# 4281->4282:G
# 4282->4283:G
# 4283->4284:A
# 4284->4285:G
# 4285->4286:C
# 4286->4287:A
# 4287->4288:C
# 4288->4289:G
# 4289->4290:A
# 4290->4291:G
# 4291->4292:G
# 4292->4293:G
# 4293->4294:A
# 4294->4295:T
# 4295->4296:G
# 1568->5814:A
# 5814->5815:T
# 5815->5816:C
# 5816->5817:A
# 5817->5818:G
# 5818->5819:A
# 5819->5820:T
# 5820->5821:A
# 5821->5822:C
# 5822->5823:G
# 5823->5824:G
# 5824->5825:C
# 5825->5826:C
# 5826->5827:A
# 5827->5828:C
# 5828->5829:G
# 5829->5830:T
# 5830->5831:C
# 5831->5832:A
# 5832->5833:C
# 5833->5834:C
# 5834->5835:T
# 5835->5836:A
# 5836->5837:T
# 5837->5838:G
# 5838->5839:A
# 5839->5840:T
# 5840->5841:G
# 5841->5842:T
# 5842->5843:C
# 5843->5844:T
# 5844->5845:T
# 5845->5846:A
# 5846->5847:A
# 5847->5848:C
# 5848->5849:A
# 5849->5850:T
# 5850->5851:A
# 5851->5852:C
# 5852->5853:A
# 5853->5854:G
# 5854->5855:A
# 5855->5856:G
# 5856->5857:C
# 5857->5858:C
# 5858->5859:G
# 5859->5860:G
# 5860->5861:G
# 5861->5862:C
# 5862->5863:G
# 5863->5864:G
# 5864->5865:A
# 5865->5866:C
# 5866->5867:G
# 5867->5868:A
# 5868->5869:A
# 5869->5870:T
# 5870->5871:C
# 5871->5872:C
# 5872->5873:A
# 5873->5874:C
# 5874->5875:C
# 5875->5876:A
# 5876->5877:T
# 5877->5878:T
# 5878->5879:C
# 5879->5880:C
# 5880->5881:G
# 5881->5882:C
# 5882->5883:A
# 5883->5884:T
# 5884->5885:G
# 5885->5886:A
# 5886->5887:A
# 5887->5888:A
# 5888->5889:G
# 5889->5890:C
# 5890->5891:T
# 5891->5892:C
# 5892->5893:G
# 5893->5894:T
# 5894->5895:A
# 5895->5896:T
# 5896->5897:T
# 5897->5898:C
# 5898->5899:A
# 254->5721:G
# 5721->5722:C
# 5722->5723:A
# 5723->5724:C
# 5724->5725:C
# 5725->5726:C
# 5726->5727:G
# 5727->5728:C
# 5728->5729:C
# 5729->5730:A
# 5730->5731:G
# 5731->5732:T
# 5732->5733:T
# 5733->5734:A
# 3808->3809:T
# 3809->3810:T
# 3810->3811:A
# 3811->3812:G
# 3812->3813:T
# 3813->3814:T
# 3814->3815:A
# 3815->3816:G
# 3816->3817:T
# 3817->3818:C
# 3818->3819:G
# 3819->3820:C
# 3820->3821:T
# 3821->3822:T
# ...
# 2090->2091:C
# 2091->2092:T
# 2092->2093:T
# 2093->2094:G
# 2094->2095:G
# 2095->2096:A
# 2096->2097:A
# 2097->2098:C
# 2098->2099:G
# 2099->2100:A
# 2100->2101:C
# 2101->2102:T
# 2102->2103:A
# 2103->2104:C
# 2104->2105:A
# 2105->2106:G
# 2106->2107:T
# 2107->2108:G
# 2108->2109:A
# 2109->2110:A
# 2110->2111:C
# 2111->2112:T
# 2112->2113:T
# 2113->2114:A
# 2114->2115:A
# 688->5184:G
# 5184->5185:T
# 5185->5186:T
# 5186->5187:G
# 5187->5188:C
# 5188->5189:C
# 5189->5190:A
# 5190->5191:A
# 5191->5192:A
# 5192->5193:T
# 5193->5194:A
# 5194->5195:A
# 5195->5196:A
# 5196->5197:G
# 5197->5198:C
# 5198->5199:T
# 5199->5200:A
# 5200->5201:A
# 5201->5202:T
# 5202->5203:A
# 5203->5204:C
# 5204->5205:A
# 5205->5206:C
# 5206->5207:C
# 5207->5208:C
# 5208->5209:G
# 5209->5210:T
# 5210->5211:G
# 5211->5212:C
# 5212->5213:A
# 5213->5214:C
# 5214->5215:C
# 5215->5216:T
# 5216->5217:C
# 5217->5218:T
# 5218->5219:T
# 5219->5220:A
# 5220->5221:G
# 5221->5222:G
# 5222->5223:G
# 5223->5224:C
# 5224->5225:G
# 5225->5226:G
# 5226->5227:T
# 5227->5228:G
# 5228->5229:C
# 5229->5230:T
# 5230->5231:C
# 5231->5232:C
# 5232->5233:G
# 5233->5234:C
# 5234->5235:T
# 5235->5236:G
# 5236->5237:T
# 5237->5238:C
# 5238->5239:G
# 5239->5240:G
# 5240->5241:A
# 5241->5242:C
# 5242->5243:T
# 5243->5244:T
# 5244->5245:T
# 5245->5246:A
# 5246->5247:G
# 5247->5248:G
# 5248->5249:T
# 5249->5250:G
# 5250->5251:T
# 5251->5252:A
# 5252->5253:G
# 5253->5254:A
# 5254->5255:T
# 5255->5256:G
# 5256->5257:G
# 5257->5258:C
# 5258->5259:T
# 5259->5260:T
# 5260->5261:G
# 5261->5262:C
# 5262->5263:G
# 5263->5264:A
# 5264->5265:A
# 5265->5266:A
# 5266->5267:T
# 5267->5268:C
# 5268->5269:T
# 5269->5270:G
# 5270->5271:A
# 5271->5272:G
# 5272->5273:G
# 687->786:T
# 786->787:A
# 787->788:A
# 788->789:C
# 789->790:T
# 790->791:G
# 791->792:G
# 792->793:A
# 793->794:G
# 794->795:G
# 795->796:A
# 796->797:A
# 797->798:T
# 798->799:G
# 799->800:G
# 800->801:G
# 801->802:G
# 802->803:A
# 803->804:A
# 804->805:T
# 805->806:A
# 806->807:C
# 807->808:C
# 808->809:T
# 809->810:C
# 810->811:C
# 811->812:A
# 812->813:C
# 813->814:G
# 814->815:T
# 815->816:G
# 816->817:G
# 817->818:A
# 818->819:C
# 819->820:T
# 820->821:G
# 821->822:G
# 822->823:G
# 823->824:C
# 824->825:G
# 825->826:G
# 826->827:T
# 827->828:A
# 828->829:T
# 829->830:G
# 830->831:A
# 831->832:A
# 832->833:G
# 833->834:C
# 834->835:A
# 835->836:A
# 836->837:T
# 837->838:G
# 838->839:T
# 839->840:T
# 840->841:G
# 841->842:C
# 842->843:C
# 843->844:G
# 844->845:T
# 845->846:G
# 846->847:A
# 847->848:C
# 848->849:A
# 849->850:A
# 850->851:T
# 851->852:A
# 852->853:A
# 853->854:T
# 854->855:G
# 855->856:T
# 856->857:T
# 857->858:G
# 858->859:C
# 859->860:T
# 860->861:A
# 861->862:G
# 862->863:A
# 863->864:C
# 864->865:C
# 865->866:G
# 866->867:A
# 786->7181:G
# 7181->7182:A
# 7182->7183:T
# 7183->7184:A
# 7184->7185:T
# 7185->7186:T
# 7186->7187:C
# 7187->7188:A
# 7188->7189:C
# 7189->7190:T
# 7190->7191:T
# 7191->7192:C
# 7192->7193:C
# 7193->7194:A
# 7194->7195:A
# 7195->7196:G
# 7196->7197:A
# 7197->7198:C
# 7198->7199:A
# 7199->7200:G
# 7200->7201:G
# 7201->7202:G
# 7202->7203:C
# 7203->7204:G
# 7204->7205:T
# 7205->7206:T
# 7206->7207:C
# 7207->7208:C
# 7208->7209:T
# 7209->7210:T
# 7210->7211:A
# 7211->7212:C
# 7212->7213:C
# 7213->7214:G
# 7214->7215:G
# 7215->7216:A
# 7216->7217:G
# 7217->7218:G
# 7218->7219:A
# 7219->7220:C
# 7220->7221:C
# 7221->7222:A
# 7222->7223:A
# 7223->7224:A
# 7224->7225:A
# 7225->7226:A
# 7226->7227:A
# 7227->7228:C
# 7228->7229:C
# 7229->7230:A
# 7230->7231:C
# 7231->7232:A
# 7232->7233:A
# 7233->7234:T
# 7234->7235:G
# 7235->7236:C
# 7236->7237:T
# 7237->7238:G
# 7238->7239:T
# 7239->7240:A
# 7240->7241:A
# 7241->7242:T
# 7242->7243:C
# 7243->7244:A
# 7244->7245:A
# 7245->7246:G
# 7246->7247:C
# 7247->7248:C
# 7248->7249:A
# 7249->7250:A
# 7250->7251:G
# 7251->7252:T
# 7252->7253:C
# 7253->7254:C
# 7254->7255:G
# 7255->7256:T
# 7256->7257:G
# 7257->7258:G
# 7258->7259:C
# 7259->7260:G
# 7260->7261:T
# 7261->7262:G
# 7262->7263:T
# 7263->7264:C
# 786->7355:T
# 7355->7356:A
# 7356->7357:A
# 7357->7358:C
# 7358->7359:T
# 7359->7360:T
# 7360->7361:A
# 7361->7362:G
# 7362->7363:T
# 7363->7364:T
# 7364->7365:A
# 7365->7366:T
# 7366->7367:A
# 7367->7368:C
# 7368->7369:A
# 7369->7370:T
# 7370->7371:T
# 7371->7372:C
# 7372->7373:C
# 7373->7374:C
# 7374->7375:G
# 7375->7376:A
# 7376->7377:T
# 7377->7378:G
# 7378->7379:A
# 7379->7380:A
# 7380->7381:A
# 7381->7382:A
# 7382->7383:T
# 3566->3567:G
# 3567->3568:T
# 3568->3569:T
# 3569->3570:C
# 3570->3571:A
# 3571->3572:G
# 3572->3573:G
# 3573->3574:C
# 3574->3575:T
# 3575->3576:T
# 3576->3577:A
# 3577->3578:T
# 3578->3579:G
# 3579->3580:A
# 3580->3581:A
# 3581->3582:G
# 3582->3583:T
# 3583->3584:A
# 3584->3585:T
# 3585->3586:G
# 3586->3587:C
# 3587->3588:G
# 3588->3589:G
# 3589->3590:A
# 3590->3591:T
# 3591->3592:T
# 3592->3593:G
# 3593->3594:T
# 3594->3595:T
# 3595->3596:C
# 3596->3597:A
# 3597->3598:T
# 3516->7265:G
# 7265->7266:G
# 7266->7267:G
# 7267->7268:C
# 7268->7269:C
# 7269->7270:C
# 7270->7271:T
# 7271->7272:T
# 7272->7273:G
# 7273->7274:C
# 7274->7275:T
# 7275->7276:A
# 7276->7277:T
# 7277->7278:A
# 7278->7279:C
# 7279->7280:A
# 7280->7281:A
# 7281->7282:A
# 7282->7283:C
# 7283->7284:T
# 7284->7285:T
# 7285->7286:A
# 7286->7287:T
# 7287->7288:C
# 7288->7289:T
# 7289->7290:C
# 7290->7291:T
# 7291->7292:A
# 7292->7293:T
# 7293->7294:A
# 7294->7295:T
# 7295->7296:G
# 7296->7297:G
# 7297->7298:C
# 7298->7299:A
# 7299->7300:T
# 7300->7301:T
# 7301->7302:C
# 7302->7303:A
# 7303->7304:T
# 7304->7305:T
# 7305->7306:C
# 7306->7307:C
# 7307->7308:C
# 7308->7309:T
# 7309->7310:G
# 7310->7311:G
# 7311->7312:A
# 7312->7313:A
# 7313->7314:T
# 7314->7315:G
# 7315->7316:T
# 7316->7317:A
# 7317->7318:C
# 7318->7319:C
# 7319->7320:A
# 7320->7321:A
# 7321->7322:C
# 7322->7323:A
# 7323->7324:G
# 7324->7325:A
# 7325->7326:A
# 7326->7327:T
# 7327->7328:C
# 7328->7329:G
# 7329->7330:C
# 7330->7331:C
# 7331->7332:A
# 7332->7333:G
# 7333->7334:C
# 7334->7335:T
# 7335->7336:T
# 7336->7337:A
# 7337->7338:A
# 7338->7339:C
# 7339->7340:A
# 7340->7341:A
# 7341->7342:A
# 7342->7343:G
# 7343->7344:C
# 7344->7345:C
# 7345->7346:C
# 7346->7347:G
# 7347->7348:A
# 7348->7349:T
# 7349->7350:A
# 7350->7351:A
# 7351->7352:G
# 7352->7353:C
# 7353->7354:A
# 686->2518:T
# 2518->2519:C
# 2519->2520:T
# 2520->2521:T
# 2521->2522:C
# 2522->2523:A
# 2523->2524:C
# 2524->2525:G
# 2525->2526:G
# 2526->2527:A
# 2527->2528:C
# 2528->2529:C
# 2529->2530:T
# 2530->2531:T
# 2531->2532:T
# 2532->2533:T
# 2533->2534:T
# 2534->2535:G
# 2535->2536:C
# 2536->2537:T
# 2537->2538:A
# 2538->2539:C
# 2539->2540:T
# 2540->2541:A
# 2541->2542:T
# 2542->2543:T
# 2543->2544:C
# 2544->2545:T
# 2545->2546:A
# 2546->2547:C
# 2547->2548:G
# 2548->2549:A
# 3330->3331:C
# 3331->3332:T
# 3332->3333:A
# 3333->3334:T
# 3334->3335:G
# 3335->3336:T
# 3336->3337:A
# 3337->3338:G
# 3338->3339:C

# %% [markdown]
# <div style="color: #000000;background-color: #EEFFEE">
#     <font size=+2>Question 1.2:</font> <font size=+1>(10 points)</font>
# <br>
# Solve the <A HREF="https://cogniterra.org/lesson/51898/step/8?unit=43387">Code Challenge: Implement Trie Matching to solve the Multiple Pattern Matching Problem</A>. Submit your solution to the challenge on Cogniterra and paste your Python code below.
#
# Notes:
# <UL>
# <LI>You do not have to follow the pseudo-code in the book, as long as you implement prefix-matching correctly that's all we need.</LI>
# <LI>You can assume that no pattern is a prefix of another pattern</LI>
# <LI>The wget below fetches the Cogniterra example input file</LI>
# </UL>
#
# </div>

# %%
# get the input
# !wget http://www.cs.ucr.edu/~stelo/cs144/data/hw2_test2.txt
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-18-d62221dfb708> in <module>
#       1 # get the input
# ----> 2 get_ipython().system('wget http://www.cs.ucr.edu/~stelo/cs144/data/hw2_test2.txt')
#
# /opt/conda/lib/python3.8/site-packages/ipykernel/zmqshell.py in system_piped(self, cmd)
#
# /opt/conda/lib/python3.8/site-packages/IPython/utils/_process_posix.py in system(self, cmd)
#
# /opt/conda/lib/python3.8/site-packages/pexpect/pty_spawn.py in __init__(self, command, args, timeout, maxread, searchwindowsize, logfile, cwd, env, ignore_sighup, echo, preexec_fn, encoding, codec_errors, dimensions, use_poll)
#
# /opt/conda/lib/python3.8/site-packages/pexpect/pty_spawn.py in _spawn(self, command, args, preexec_fn, dimensions)
#
# /opt/conda/lib/python3.8/site-packages/pexpect/pty_spawn.py in _spawnpty(self, args, **kwargs)
#
# /opt/conda/lib/python3.8/site-packages/ptyprocess/ptyprocess.py in spawn(cls, argv, cwd, env, echo, preexec_fn, dimensions)
#
# OSError: [Errno 107] Transport endpoint is not connected

# %%
## YOUR CODE HERE
## no tree/graph/tries libraries allowed

def prefix_matching(trie, word):
    """ Return a pair (boolean, string) where <boolean> is True if-and-only-if a non-empty prefix of <word> occurs in the <trie>
    and <string> is the prefix of <word> that matched  """
    ## YOUR CODE HERE
    node =0 
    i=0
    while i<len(word): #traverse entire word checking all chars 
        char =word[i]
        if char in trie[node]: #if the beginning of a substring, we keep traversing to see if entire substring is there
            node = trie[node][char]
            i=i+1
            if len(trie[node])==0: #if this is a leaf, it means we found entire pattern!
                return True, word[:i]
        else:
            return False, ''

    return False, ''

with open("hw2_test23.txt", "r") as f: # open the file
    alllines = [line.rstrip() for line in f]
text = alllines[0]               # text is on the first line
l = alllines[1:]                 # this is the list of words

hits = {}                        # save the hits for each pattern in a dictionary, where the key is the word
for word in l:                   # for the example in Stepik we expect that hits = {'ATCG': [1, 11], 'GGGT': [4, 15]}
    hits[word] = []              # initially each pattern has an empty list of occurrences, we will append to these
    
trie = make_trie(l)              # create the trie using the code in the previous problem

# YOUR CODE HERE
# call prefix_matching(trie, ?) iteratively on each suffix of <text> 
# save the occurrences of each pattern in the dictionary <hits>
for i in range(len(text)):
    found, matched = prefix_matching(trie,text[i:]) 
    if found:
        hits[matched].append(i) #if we found it, append the index of where it was found
allhits = []
for word in hits:
    allhits += hits[word]
print(' '.join(map(str,sorted(allhits)))) # print the list of hits according to the required format
# Out:
# 8 271 278 704 798 1132 1410 1697 2100 2107 2224 2231 2358 2365 2978 2985 3038 3045 3377 3384 3566 3593 3805 3812 4111 4118 4162 4169 4244 4251 5170 5177 5713 5720 6037 6254 6261 6547 6554 7431 8157 8528 8535

# %% [markdown]
# <div style="color: #000000;background-color: #EEFFEE">
#     <font size=+2>Question 2.1</font> <font size=+1>(15 points)</font>
# <br>
# To solve the <A HREF="https://cogniterra.org/lesson/51899/step/5?unit=43388">Code Challenge: Solve the Longest Repeat Problem</A> we will start from a clean Python <A href="https://nbviewer.jupyter.org/gist/BenLangmead/6665861">implementation</A> of suffix trees by Ben Langmead at JHU. Please note that this implementation takes quadratic time in the input size. More time and memory-efficient implementation are available for Python. Ben's accompanying slides are <A href="http://www.cs.jhu.edu/~langmea/resources/lecture_notes/suffix_trees.pdf">here</A>, along with other great <A href="http://www.langmead-lab.org/teaching.html">teaching material</A> for bioinformatics and string processing.
# <br>
# I have added a new function <B>traverse</B> to Ben's code that visits the suffix tree in DFS order and prints the label on the edges with their level number.
# <br>
# You will need to write Python code for a similar function <B>longestRepeat</B> that finds the longest repeated string using the suffix tree.
# </div>

# %% [markdown]
# <hr style="height:5px;border-width:2;color:gray;background-color:#000000">
# <center><h1>Question 2: Suffix trees</h1></center>
# <br>
# A suffix tree is a compressed trie containing all the suffixes of the given text as their keys and positions in the text as their values. Suffix trees allow particularly fast implementations of many important string operations. In the following question, we will gain some experience in using them to solve text processing problems.
#
# We will <b>skip</b> the following three coding challenges in the book
# <UL>
# <LI> <A HREF="https://cogniterra.org/lesson/51899/step/4?unit=43388">Code Challenge: Solve the Suffix Tree Construction Problem</A></LI>
# <LI> <A HREF="https://cogniterra.org/lesson/51899/step/6?unit=43388">Code Challenge: Solve the Longest Shared Substring Problem</A></LI>
# <LI> <A HREF="https://cogniterra.org/lesson/51899/step/7?unit=43388">Code Challenge: Solve the Shortest Non-Shared Substring Problem</A></LI>
# </UL>
# Again,these three challenges above are OPTIONAL. They are good problems, but you do not need to solve it, unless you feel inclined to do so.

# %%
# get the input
# !wget http://www.cs.ucr.edu/~stelo/cs144/data/hw2_test3.txt
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-5-0883d5664ee9> in <module>
#       1 # get the input
# ----> 2 get_ipython().system('wget http://www.cs.ucr.edu/~stelo/cs144/data/hw2_test3.txt')
#
# /opt/conda/lib/python3.8/site-packages/ipykernel/zmqshell.py in system_piped(self, cmd)
#
# /opt/conda/lib/python3.8/site-packages/IPython/utils/_process_posix.py in system(self, cmd)
#
# /opt/conda/lib/python3.8/site-packages/IPython/utils/_process_posix.py in sh(self)
#
# OSError: "/bin/bash" shell not found

# %%
## no tree/graph/tries libraries allowed
## code adapted from https://nbviewer.jupyter.org/gist/BenLangmead/6665861

class SuffixTree(object):
    
    class Node(object):
        
        def __init__(self, lab):
            self.lab = lab # edge label
            self.out = {}  # outgoing edges; maps characters to nodes

        def traverse(self,level):
            """ Traverse the suffix tree in DFS order and prints the
                label on the edges with their level number """
            for x in self.out:          # x is the first letter of the outgoing edge, if self.out=={} we are in a leaf and the for loop is not executed
                child = self.out[x]     # out[x] gives the pointer to the children with an edge that starts with x
                print(level,child.lab)
                child.traverse(level+1) # visit recursively the child

        def longestRepeat(self,s):
            global longest
            """ Returns the longest repeated string by finding the internal node in the suffix
                tree that corresponds to the longest string from the root """
            ## YOUR CODE HERE
            ## this function is almost identical to traverse()
            ## start with traverse() as a template, and save in the global variable <longest> the
            ## longest repeated string encountered so far during the traversal
            for x in self.out: #same as traverse:
                child = self.out[x]
                path = s+child.lab
                if len(child.out)>0:  #if there is a leaf (not empty)
                    if len(path)>len(longest): #if the leaf takes to longest, update longest
                        longest = path   #this is updating the longest w the new one we found in the leaf node
                    child.longestRepeat(path)
            
            
    def __init__(self, s):
        """ Make suffix tree, without suffix links, from s in quadratic time
            and linear space """
        s += '$'
        self.root = self.Node(None)
        self.root.out[s[0]] = self.Node(s) # trie for just longest suf
        # add the rest of the suffixes, from longest to shortest
        for i in range(1, len(s)):
            # start at root; we’ll walk down as far as we can go
            cur = self.root
            j = i
            while j < len(s):
                if s[j] in cur.out:
                    child = cur.out[s[j]]
                    lab = child.lab
                    # Walk along edge until we exhaust edge label or
                    # until we mismatch
                    k = j+1 
                    while k-j < len(lab) and s[k] == lab[k-j]:
                        k += 1
                    if k-j == len(lab):
                        cur = child # we exhausted the edge
                        j = k
                    else:
                        # we fell off in middle of edge
                        cExist, cNew = lab[k-j], s[k]
                        # create “mid”: new node bisecting edge
                        mid = self.Node(lab[:k-j])
                        mid.out[cNew] = self.Node(s[k:])
                        # original child becomes mid’s child
                        mid.out[cExist] = child
                        # original child’s label is curtailed
                        child.lab = lab[k-j:]
                        # mid becomes new child of original parent
                        cur.out[s[j]] = mid
                else:
                    # Fell off tree at a node: make new edge hanging off it
                    cur.out[s[j]] = self.Node(s[j:])
    
    def followPath(self, s):
        """ Follow path given by s.  If we fall off tree, return None.  If we
            finish mid-edge, return (node, offset) where 'node' is child and
            'offset' is label offset.  If we finish on a node, return (node,
            None). """
        cur = self.root
        i = 0
        while i < len(s):
            c = s[i]
            if c not in cur.out:
                return (None, None) # fell off at a node
            child = cur.out[s[i]]
            lab = child.lab
            j = i+1
            while j-i < len(lab) and j < len(s) and s[j] == lab[j-i]:
                j += 1
            if j-i == len(lab):
                cur = child # exhausted edge
                i = j
            elif j == len(s):
                return (child, j-i) # exhausted query string in middle of edge
            else:
                return (None, None) # fell off in the middle of the edge
        return (cur, None) # exhausted query string at internal node
    
    def hasSubstring(self, s):
        """ Return true iff s appears as a substring """
        node, off = self.followPath(s)
        return node is not None
    
    def hasSuffix(self, s):
        """ Return true iff s is a suffix """
        node, off = self.followPath(s)
        if node is None:
            return False # fell off the tree
        if off is None:
            # finished on top of a node
            return '$' in node.out
        else:
            # finished at offset 'off' within an edge leading to 'node'
            return node.lab[off] == '$'
           
    def traverse(self):
        return self.root.traverse(0)

    def longestRepeat(self):
        global longest
        longest = ''
        self.root.longestRepeat('')
        return longest

f = open("hw2_test3.txt", "r")         # open the file
text = f.readline().strip()            # text is on the first line

# MAKE THE SUFFIX TREE
stree = SuffixTree(text)
#stree.traverse()
stree.longestRepeat()
# Out:
# 'TATCGTT'
